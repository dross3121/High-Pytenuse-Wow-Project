# %% [markdown]
# # Api for GitHub jobs Wow project

# %% [markdown]
# ## Import packages request and pprint

# %%
import pandas as pd
import json
import requests
import pprint

# %%
r= requests.get('https://jobs.github.com/positions.json?{page}')

# %% [markdown]
# ## While loop and for loop to iterate the data received from Api and parse the data i want to work with (company, title, location and url)

# %%
page = 1
more_pages = True
title = 'title'
company = 'company'
url = 'url'
location = 'location'
all_data = []

while more_pages:
    
    r= requests.get(f'https://jobs.github.com/positions.json?page={page}')
    
    for HPS in r.json():
        results = {
        "Company" : HPS[company],
        "Title": HPS[title],
        "Location": HPS[location],
         "Url": HPS[url]
        
        }
        all_data.append(results)
    
    nextpage = requests.get(f'https://jobs.github.com/positions.json?page={page+1}')

    if len(nextpage.json()) == 0:
        more_pages = False
            
         
    page+=1    
        
result = pd.DataFrame(all_data)
result.to_csv('Jobs_GitHub.csv')

# %%
pd.read_csv('Jobs_GitHub.csv')
# Out:
#      Unnamed: 0                            Company  \
# 0             0                           Rabobank
# 1             1                       Marketcircle
# 2             2  Kiron Open Higher Education gGmbH
# 3             3                  talentsconnect AG
# 4             4                     InnoGames GmbH
# ..          ...                                ...
# 155         155            Synedat Consulting GmbH
# 156         156                     InnoGames GmbH
# 157         157                             Playco
# 158         158                            Whizora
# 159         159                         ResoluteAI
#
#                                                  Title              Location  \
# 0                                      Scrum Master IT               Utrecht
# 1                               Senior Rails Developer  Toronto, ON - REMOTE
# 2    Software Engineer (Javascript, GraphQL & Posit...                Berlin
# 3                          Chapter-Lead DevOps (w/m/d)      Cologne, Germany
# 4    Senior Mobile Game Developer (C++) - Forge of ...               Hamburg
# ..                                                 ...                   ...
# 155                       IT-Architekt Manager (m/w/d)             Helmstedt
# 156                Java Software Developer - Core Team               Hamburg
# 157                          Senior Fullstack Engineer                Remote
# 158                   Full-Stack Application Developer                Remote
# 159                                Full Stack Engineer         New York City
#
#                                                    Url
# 0    https://jobs.github.com/positions/e3b220e2-de8...
# 1    https://jobs.github.com/positions/acd6abe6-693...
# 2    https://jobs.github.com/positions/01c2b3f1-a21...
# 3    https://jobs.github.com/positions/00e66b8d-232...
# 4    https://jobs.github.com/positions/068da99c-e3d...
# ..                                                 ...
# 155  https://jobs.github.com/positions/6453c3a6-7fc...
# 156  https://jobs.github.com/positions/ffe637f1-603...
# 157  https://jobs.github.com/positions/46ab84b4-12d...
# 158  https://jobs.github.com/positions/b915a744-6f6...
# 159  https://jobs.github.com/positions/4926de97-add...
#
# [160 rows x 5 columns]
