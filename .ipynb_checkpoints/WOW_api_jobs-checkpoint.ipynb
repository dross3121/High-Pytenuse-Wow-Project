# %% [markdown]
# # My Api practice for Wow project

# %% [markdown]
# ## import packages request and pprint

# %%
import requests
import pprint

# %% [markdown]
# ## using requests.get() from the request package we'll be able to access api for github job making the "description and pages dynamic (ex: description = 'description=ruby' page = 'page=') and replacing these in the HTTP wiht {} i'll be able to access the site in real time.

# %%
description = 'description='
page = 'page='
search = 'search='
# r= request.get('https://jobs.github.com/positions.json?description=ruby&page=1')

r = requests.get('https://jobs.github.com/positions.json?{description}&{pages}')

# %% [markdown]
# ## calling the pprint package and using the pprint function in that package along with the .json() from the requests package we are able to print the contents of the web page.

# %%
# pprint.pprint(r.json())

# %% [markdown]
# ## some example code access the list of dicts for the api

# %%
# pprint.pprint(r.json()[1]['company'])
# pprint.pprint(r.json()[1]['location'])
# pprint.pprint(r.json()[1]['url'])

# %% [markdown]
# ## A for loop to iterate the data received from Api and parse the data i want to work with (company, title, location and url)

# %%
search = []
title = 'title'
company = 'company'
url = 'url'
location = 'location'

for HPS in r.json():
        pprint.pprint(HPS[company]),
        pprint.pprint(HPS[title]),
        pprint.pprint(HPS[location]),
        pprint.pprint(HPS[url])
    


          
# print(r.json()[0][title],r.json()[0][company],r.json()[HPS][url],r.json()[0][location])      
#     print(r.json()[0]['title'],r.json()[0]['company'],r.json()[0]['url'],r.json()[0]['location'])
# print(r.json()[1]['title'],r.json()[1]['company'],r.json()[1]['url'],r.json()[1]['location'])
#     break
# Out:
# 'eHealth Innovation @ UHN'
# 'iOS Developer'
# 'Toronto, Canada (or remote within Canada)'
# 'https://jobs.github.com/positions/ff9219e4-6cb7-4e22-9beb-d660ef2edfb5'
# 'Defendify'
# 'Senior Full Stack Developer'
# 'Portland, ME (Remote OK)'
# 'https://jobs.github.com/positions/912fc53b-1b7f-427a-bc69-25f03b597f8c'
# 'Renewi'
# 'Infrastructure Designer'
# 'eindhoven '
# 'https://jobs.github.com/positions/1ea82024-3a55-4a55-9a46-cb9c84220ce3'
# 'LILLYDOO GmbH'
# '(Senior) Frontend Developer (f/m/d)'
# 'Frankfurt, Germany (remote within Germany)'
# 'https://jobs.github.com/positions/c1c29e32-4caa-4831-89d6-ded3e6ca42f0'
# 'StackFuel GmbH'
# 'Head of Engineering [m/w/d]'
# 'Berlin'
# 'https://jobs.github.com/positions/e89d6f0e-59b4-4cd1-9b9f-5374877f8854'
# 'Rabobank'
# 'Junior CI/CD Engineer'
# 'Croeselaan 18, 3521CB, Utrecht'
# 'https://jobs.github.com/positions/9b316dca-5884-4a72-a053-47d745fdec3b'
# 'Amazon Web Services AWS'
# 'Senior Front-End Engineer'
# 'Berlin'
# 'https://jobs.github.com/positions/fddb7d4c-d7e0-4056-8d9a-89d5731f6a33'
# 'Amenitiz'
# 'Senior Backend Developer (RoR)'
# 'Barcelona'
# 'https://jobs.github.com/positions/286d8321-c5e5-4311-82b5-1756e5393199'
# 'Amazon Web Services AWS'
# 'Sr. Software Development Engineer - Amazon Redshift'
# 'Berlin'
# 'https://jobs.github.com/positions/41e6da3c-3667-472f-a78e-039614ec5c1d'
# 'Amazon Web Services AWS'
# 'Senior Software Development Engineer - AWS Billing'
# 'Berlin'
# 'https://jobs.github.com/positions/9f2b589e-76f2-4052-b17d-cd6fa046aa00'
# 'Amazon Web Services AWS'
# 'Senior Software Development Engineer - Amazon Web Services - Berlin (m/f)'
# 'Berlin'
# 'https://jobs.github.com/positions/de6af81b-f0fd-40d1-832c-3680fd56f6e0'
# 'Amazon Web Services AWS'
# 'Senior Software developer - Kernel Engineer'
# 'Dresden'
# 'https://jobs.github.com/positions/3270824f-79f4-4600-9dbd-915e8573f51e'
# 'Amazon Web Services AWS'
# 'Software Development Engineer - Amazon Redshift Spectrum'
# 'Berlin'
# 'https://jobs.github.com/positions/79544da5-c2e1-4a58-9141-887f82aff720'
# 'Amazon Web Services AWS'
# 'Software Development Engineer - Amazon Redshift SQL Compiler'
# 'Berlin'
# 'https://jobs.github.com/positions/acae0e98-7cbd-43d5-891a-3ada33637f76'
# 'Amazon Web Services AWS'
# 'Software Development Engineer – Backend – AWS Console Platform'
# 'Berlin'
# 'https://jobs.github.com/positions/2dd205cd-99cd-4d7d-9993-71b848758c01'
# 'Amazon Web Services AWS'
# 'Software Development Engineer'
# 'Dresden'
# 'https://jobs.github.com/positions/6a1b8822-cf30-478f-887a-a989fff53b31'
# 'Amazon Web Services AWS'
# 'Software Development Engineer - AWS Identity'
# 'Berlin'
# 'https://jobs.github.com/positions/33f85014-0510-47d6-9fe6-7e8134a246b2'
# 'Amazon Web Services AWS'
# 'Sr. Software Development Engineer - AWS'
# 'Aachen'
# 'https://jobs.github.com/positions/24a037f5-0fc6-45f2-8288-90ee484d741c'
# 'Renewi'
# 'Salesforce Tester'
# 'Eindhoven '
# 'https://jobs.github.com/positions/beeb797b-1793-4de4-a72c-96cb638ce7f0'
# 'bene : studio'
# 'Senior React & Node Engineer (Remote / Relocation to European Union)'
# 'Budapest'
# 'https://jobs.github.com/positions/86fb6ad3-abc3-4ac7-aa02-54514d45c456'
# 'Usercentrics GmbH'
# 'UI Team Lead Software Engineer ( React or Angular ) (m / f / d)'
# 'Munch Germany '
# 'https://jobs.github.com/positions/ea2899d5-c9ca-40cd-b5ca-4221714c03f7'
# 'Pinpoint'
# 'Senior Software Developer (Rails & React)'
# 'St. Helier, Jersey'
# 'https://jobs.github.com/positions/9e6f0ccf-69dc-4a58-8b75-ecb4a81eed25'
# 'Usercentrics GmbH'
# 'Senior Software Engineer ( React ) (m / f / d)'
# 'Munich Germany'
# 'https://jobs.github.com/positions/23142439-c599-420c-a456-2af883055b77'
# 'Canon Medical Research USA, Inc.'
# 'Senior/Principal Embedded Software Engineer (CT)'
# 'Vernon Hills, IL (Chicago)'
# 'https://jobs.github.com/positions/0bbcbdda-acf3-490a-9903-f3b711d0b8d8'
# 'Frontline Wildfire'
# 'Senior Software Engineer'
# 'Remote (US Pacific TZ)'
# 'https://jobs.github.com/positions/dfa9f75c-7be5-449c-a152-c3eabf915223'
# 'Linqto, Inc.'
# 'Senior Software Engineer'
# 'Remote in U.S.'
# 'https://jobs.github.com/positions/1d837bd6-9265-4a88-bc9d-9cbc07908857'
# 'LogicFlow AG'
# 'LogicFlow AG'
# 'Zurich'
# 'https://jobs.github.com/positions/04c55caa-3e46-42ae-94e9-05163eb5dd3e'
# 'Shell Business operations, Chennai'
# 'Associate Data Scientist'
# 'Chennai'
# 'https://jobs.github.com/positions/c2beb2b6-9190-4ca7-b0ca-7804b768dc87'
# 'Shell Business operations, Chennai'
# 'Data Scientist - Retail'
# 'Chennai'
# 'https://jobs.github.com/positions/2315d8ae-9e9b-4b73-a98e-8c383cdf532e'
# 'Shell Business operations, Bangalore'
# 'Full Stack Engineer'
# 'Bangalore'
# 'https://jobs.github.com/positions/3fc15bd7-3217-4526-a805-2a48364c5a11'
# 'Universiteit Utrecht '
# 'Research Engineer (0.8 - 1.0 FTE)'
# 'Utrecht '
# 'https://jobs.github.com/positions/247ed817-b1e5-4b2c-b9eb-3733b69aefb8'
# 'Shell Business operations, Bangalore'
# 'Machine Learning Engineer'
# 'Bangalore'
# 'https://jobs.github.com/positions/03f76ce2-213b-43aa-8127-7e6885a08a28'
# 'Shell Business operations, Chennai'
# 'Data Science Team Lead'
# 'Chennai'
# 'https://jobs.github.com/positions/9cc73009-b73d-4ed0-a6b3-7da236236464'
# 'Farmy AG'
# 'Ruby on Rails Platform Team-Lead'
# 'Barcelona'
# 'https://jobs.github.com/positions/cd7378a6-5fe3-4cf2-a55f-3726f850813b'
# 'Shell Business operations, Bangalore'
# 'Sr. Machine Learning Engineer'
# 'Bangalore'
# 'https://jobs.github.com/positions/e0714497-d1b7-4411-b6b6-39cf49bc3a24'
# 'Shell India Markets Pvt. Ltd.'
# 'HPC & AI Resident'
# 'Bangalore'
# 'https://jobs.github.com/positions/6c5e30ab-4485-4505-8693-8056bacefb47'
# 'Bayerischer Rundfunk'
# 'Senior Mobile Developer (m/w/d) in Vollzeit/Teilzeit'
# 'München'
# 'https://jobs.github.com/positions/77e4b693-ce7d-49c9-973c-8313c2c03018'
# 'Alakaina Foundation Family of Companies'
# 'Data Center Engineer/Virtualization Architect'
# 'Fort Gordon, GA'
# 'https://jobs.github.com/positions/6c83f405-17ba-48c1-a748-c372852a153b'
# 'Atmosphere TV'
# 'DevOps Engineer'
# 'Austin, TX'
# 'https://jobs.github.com/positions/42318b2e-ce14-468f-a6fc-c39e0cdef359'
# 'Limango'
# 'Backend Developer (m/w/d) Operations'
# 'Munich'
# 'https://jobs.github.com/positions/5acc3a35-6684-4d2a-9142-adc6bfac53e4'
# 'Container xChange'
# 'Software Engineer (Java, Angular) (f/m/d)'
# 'Hamburg'
# 'https://jobs.github.com/positions/99481c34-2348-4881-81b4-588fd3ea4640'
# 'Royal FloraHolland Aalsmeer'
# 'Infrastructure Architect'
# 'Aalsmeer'
# 'https://jobs.github.com/positions/61140587-9828-47ab-af19-7cf7b42e905d'
# 'Exact'
# 'Senior Software Engineer .NET'
# 'Delft'
# 'https://jobs.github.com/positions/045efb98-2e50-41dc-971a-1ea9a90a3ddc'
# 'Hubble_s'
# 'Full Stack Developer'
# 'Europe (remote)'
# 'https://jobs.github.com/positions/bcf29c85-8bb5-4663-9d55-f12b1349f624'
# 'talentsconnect AG'
# 'Senior Full Stack Java Developer (w/m/d)'
# 'Cologne, Germany'
# 'https://jobs.github.com/positions/102e22a9-af03-4d21-b0c9-6c40063d26e1'
# 'Flyclops'
# 'Senior Software Engineer'
# 'Philadelphia'
# 'https://jobs.github.com/positions/953e8a4f-cf2c-4015-a544-3f7cbb5d8e03'
# 'Atlantic Food Labs GmbH'
# 'Co-Founder & CTO (m,f,x)'
# 'Berlin'
# 'https://jobs.github.com/positions/62abf53b-bd52-48dd-b014-acc28c63bdd1'
# 'DoctorBox GmbH'
# 'iOS Developer (f/m/d)'
# 'Berlin'
# 'https://jobs.github.com/positions/cec4fc5b-3d4b-4014-8c96-470e93504c02'
# 'Raycast'
# 'Developer Advocate'
# 'Remote, EU'
# 'https://jobs.github.com/positions/4621ed62-9f09-4d25-8694-24291ccde35c'
# 'Microsoft'
# 'Microsoft Software Engineer. Dublin, Ireland.'
# 'Dublin, Ireland'
# 'https://jobs.github.com/positions/aa5a4c42-7a7a-4513-9de6-a0daeba36d87'
