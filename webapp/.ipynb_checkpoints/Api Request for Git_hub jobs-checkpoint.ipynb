# %%
import pandas as pd
import csv
import json
import requests

# %%
page = 1
more_pages = True
title = 'title'
company = 'company'
url = 'url'
location = 'location'
all_data = []

while more_pages:
    
    r= requests.get(f'https://jobs.github.com/positions.json?page={page}')
    
    for HPS in r.json():
        results = {
        "Job Title": HPS[title],
        "Company": HPS[company], 
        "Location": HPS[location],
         "Job Url": HPS[url]
        
        }
        all_data.append(results)
    
    nextpage = requests.get(f'https://jobs.github.com/positions.json?page={page+1}')

    if len(nextpage.json()) == 0:
        more_pages = False
            
         
    page+=1    
        
result = pd.DataFrame(all_data)
result.to_csv('Jobs_GitHub.csv')

# %%
pd.read_csv('Jobs_GitHub.csv')
# Out:
#      Unnamed: 0                                          Job Title  \
# 0             0  Experienced Full Stack Web Developer - London-...
# 1             1         Golang and Kubernetes Platform Engineering
# 2             2                                Solutions Architect
# 3             3                                 Back-end developer
# 4             4                            Cloud Engineer (medior)
# ..          ...                                                ...
# 253         253          Senior BackEnd Engineer - Finance (f/m/d)
# 254         254                                 Back End Developer
# 255         255                                 Back End Developer
# 256         256  Senior UX Designer/Web-Developer/Senior Web-De...
# 257         257                           Senior Frontend Engineer
#
#                     Company               Location  \
# 0         Mas & Pas Limited                London
# 1               Secureworks                 Remote
# 2                    Cyware               Anywhere
# 3                   xential  Drachten, Netherlands
# 4                  WoodWing                Zaandam
# ..                      ...                    ...
# 253  fotograf.de / GotPhoto                 Berlin
# 254                Vaultoro                 Berlin
# 255      Excelerate America            Detroit, MI
# 256       cusati media GmbH                 Remote
# 257                  Remote               Anywhere
#
#                                                Job Url
# 0    https://jobs.github.com/positions/0e9ae5fa-5bb...
# 1    https://jobs.github.com/positions/f4b18395-b29...
# 2    https://jobs.github.com/positions/4b46a3fb-6a7...
# 3    https://jobs.github.com/positions/2b9d4a83-aa5...
# 4    https://jobs.github.com/positions/0bbffc5b-d52...
# ..                                                 ...
# 253  https://jobs.github.com/positions/2bab688a-f8c...
# 254  https://jobs.github.com/positions/6f7ca396-7c8...
# 255  https://jobs.github.com/positions/e55930c6-0db...
# 256  https://jobs.github.com/positions/5d895623-931...
# 257  https://jobs.github.com/positions/3cc340d4-666...
#
# [258 rows x 5 columns]
