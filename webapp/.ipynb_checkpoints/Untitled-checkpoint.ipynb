# %%
import pandas as pd
import csv
import json
import requests

# %%
page = 1
more_pages = 'Jobs_GitHub.csv'
title = 'title'
company = 'company'
url = 'url'
location = 'location'
all_data = []

while more_pages:
    r= pd.read_csv('Jobs_GitHub.csv')
    
#     r= requests.get(f'https://jobs.github.com/positions.json?page={page}')
    
    for HPS in r:
#         .json()
        results = {
        "Company" : HPS[company],
        "Title": HPS[title],
        "Location": HPS[location],
         "Url": HPS[url]
        
        }
#         all_data.append(results)
print(HPS)   
#     nextpage = requests.get(f'https://jobs.github.com/positions.json?page={page+1}')

#     if len(nextpage.json()) == 0:
#         more_pages = False
            
         
#     page+=1    
        
# result = pd.DataFrame(all_data)
# result.to_csv('Jobs_GitHub.csv')

# %%
pd.read_csv('Jobs_GitHub.csv')
# Out:
#      Unnamed: 0              Company  \
# 0             0           Channable
# 1             1           ExpressVPN
# 2             2           ExpressVPN
# 3             3               Playco
# 4             4           PAI Health
# ..          ...                  ...
# 129         129               Prisma
# 130         130   Spear Technologies
# 131         131            Fullstack
# 132         132  MILES Mobility GmbH
# 133         133                 TAUR
#
#                                         Title                        Location  \
# 0                    Python Software Enginer        Utrecht (The Netherlands)
# 1                API Engineer / API Developer                       Singapore
# 2              Server-side Software Developer        London / Poznan / Remote
# 3                       Core/Backend Engineer                          Remote
# 4                      Senior DevOps Engineer     Vancouver, British Columbia
# ..                                        ...                             ...
# 129             Technical Lead: Control Plane     Remote, or Berlin (Germany)
# 130          Experienced Power Apps developer  remote - must be located in US
# 131  Fullstack Mobile Engineer (React Native)                          Remote
# 132                 Frontend Engineer (f/m/x)                          Berlin
# 133                 Senior Back End Developer                          London
#
#                                                    Url
# 0    https://jobs.github.com/positions/568f9a99-186...
# 1    https://jobs.github.com/positions/3c0a7081-3d1...
# 2    https://jobs.github.com/positions/c05204de-9a3...
# 3    https://jobs.github.com/positions/46ab84b4-12d...
# 4    https://jobs.github.com/positions/fbc2dac0-f27...
# ..                                                 ...
# 129  https://jobs.github.com/positions/481a576c-a28...
# 130  https://jobs.github.com/positions/efe2509d-a7c...
# 131  https://jobs.github.com/positions/619735aa-7ba...
# 132  https://jobs.github.com/positions/8732a0b3-2af...
# 133  https://jobs.github.com/positions/7c329734-354...
#
# [134 rows x 5 columns]
